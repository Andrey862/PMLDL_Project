# %%
#!g1.1
# !git clone https://github.com/nerel-ds/NEREL

# %%
# !unzip NEREL-v1.0.zip -d NEREL

# %%
#!g1.1
## Read the data# Reading files
from collections import namedtuple
import re
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import nltk

Ann = namedtuple('annotation', ['tag', 'start1', 'end1', 'start2', 'end2', 'text'])
Rel = namedtuple('relationship', ['tag', 'arg1', 'arg2'])

def read_files(folder):
    filenames = sorted(set(e[:e.rfind('.')] for e in os.listdir(folder)))[1:]
    
    texts, entities, relationships  = [], [], []
    for file in tqdm(filenames):
       # if (not file): continue
        path1 = os.path.join(folder, file+'.txt')
        path2 = os.path.join(folder, file+'.ann')
        if (not os.path.exists(path2)):
            print(f'{path2} not found')
            continue
            #with open(path2, 'w'):
            #    pass
            
        with open(path1, 'r', encoding="utf8") as text, open(path2, 'r', encoding="utf8") as ann:
            texts.append(text.read())

            file_entities = {}
            file_relationship = []
            regex_ent = r'T(?P<id>\d+)\s(?P<tag>\w+)\s(?P<start1>\d+) (?P<end1>\d+)(;(?P<start2>\d+) (?P<end2>\d+))?\s(?P<text>.*)'
            regex_rel = r'R(?P<id>\d+)\s(?P<tag>\w+)\sArg1:T(?P<arg1>\d+) Arg2:T(?P<arg2>\d+)'
            
            
            for row in sorted(ann.readlines(), reverse=True):
                #print(row)
                match_ent = re.match(regex_ent, row)
                match_rel = re.match(regex_rel, row)
                if (match_ent):
                    res = match_ent.groupdict()
                    res['start1'] = int(res['start1'])
                    res['end1'] = int(res['end1'])
                    if (res['start2'] is not None):
                        res['start2'] = int(res['start2'])
                        res['end2'] = int(res['end2'])
                    id = res.pop('id')
                    file_entities[id] = Ann(**res)
                elif (match_rel):
                    try:
                        res = match_rel.groupdict()
                        res['arg1'] = file_entities[res['arg1']]
                        res['arg2'] = file_entities[res['arg2']]
                        id = res.pop('id')
                        file_relationship.append(Rel(**res))
                    except KeyError as e:
                        print(f'not found T{e} row={row}')
                else:
                    print(f'incorrect format in: row={row} file={file}')
            entities.append(file_entities)
            relationships.append(file_relationship)
    entities = [sorted(e.values(), key = lambda x: (x.start1, x.end1)) for e in entities]
    return texts, entities, relationships, filenames

# %%
#!g1.1
folder = 'NEREL/NEREL-v1.0/train'
texts, entities, relationships, filenames = read_files(folder)
# Out:
# incorrect format in: row=По словам очевидцев пешехо
#  file=21013_text
# 100%|██████████| 745/745 [00:01<00:00, 468.29it/s]

# %%
#!g1.1
def in_range(range1, range2):
    # range1 in range2
    if range1[0] is None: return True
    if range2[0] is None: return False
    return int(range2[0]) <= int(range1[0]) and int(range2[1]) >= int(range1[1])

def is_nested_anns(ent1: Ann, ent2: Ann):
    # ent 1 in ent 2
    res = True
    ent1_range1 = (ent1.start1, ent1.end1)
    ent1_range2 = (ent1.start2, ent1.end2)
    ent2_range1 = (ent2.start1, ent2.end1)
    ent2_range2 = (ent2.start2, ent2.end2)
    #print(f'{ent1_range1=} {ent1_range2=} {ent1_range2=} {ent2_range2=}')
    res = res and (in_range(ent1_range1, ent2_range1) or in_range(ent1_range1, ent2_range2))
    res = res and (in_range(ent1_range2, ent2_range1) or in_range(ent1_range2, ent2_range2))
    return res


def is_nested_anns2(ent1: Ann, ent2: Ann):
    return is_nested_anns(ent1,ent2) or is_nested_anns(ent2, ent1)

def is_nested(rel: Rel):
    return is_nested_anns(rel.arg1, rel.arg2) or is_nested_anns(rel.arg2, rel.arg1)

# %% [markdown]
# ![](https://i.imgur.com/tgDfc8i.png)             | ![](https://i.imgur.com/oWa5vWo.png)
# :-------------------------:|:-------------------------:

# %%
#!g1.1
# %pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (2.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.50.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from transformers) (0.1.96)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.12.31)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2021.7.6)
# Requirement already satisfied: tokenizers==0.5.2 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: requests in /kernel/lib/python3.7/site-packages (from transformers) (2.25.1)
# Requirement already satisfied: numpy in /kernel/lib/python3.7/site-packages (from transformers) (1.19.4)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->transformers) (0.10.0)
# Requirement already satisfied: botocore<1.16.0,>=1.15.31 in /usr/local/lib/python3.7/dist-packages (from boto3->transformers) (1.15.49)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from boto3->transformers) (0.3.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /kernel/lib/python3.7/site-packages (from botocore<1.16.0,>=1.15.31->boto3->transformers) (2.8.2)
# Requirement already satisfied: urllib3<1.26,>=1.20 in /home/jupyter/.local/lib/python3.7/site-packages (from botocore<1.16.0,>=1.15.31->boto3->transformers) (1.25.11)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.7/dist-packages (from botocore<1.16.0,>=1.15.31->boto3->transformers) (0.15.2)
# Requirement already satisfied: six>=1.5 in /kernel/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.16.0,>=1.15.31->boto3->transformers) (1.16.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /kernel/lib/python3.7/site-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /kernel/lib/python3.7/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /kernel/lib/python3.7/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# # Dataset

# %%
#!g1.1
import os
import torch
import time
import torch.optim as optim
from torch.utils.data import DataLoader
import numpy as np
from tqdm.notebook import tqdm
import torchvision
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from matplotlib import pyplot as plt
import random
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
#!g1.1
from transformers import BertForSequenceClassification, BertTokenizer

# %%
#!g1.1
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# Using cuda device

# %%
#!g1.1
tokenizer = BertTokenizer.from_pretrained('DeepPavlov/rubert-base-cased-sentence')
# Out:
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=1649718.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=112.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=24.0), HTML(value='')))

# %%
#!g1.1
MAX_LENGTH = 100

# %%
#!g1.1
# import nltk
# nltk.download('punkt')
# #!g1.1
# sents = nltk.sent_tokenize(texts[0])
# len(' '.join(sents))

# %%
#!g1.1
class Binary_Tag:
    def __getitem__(self, x):
        if (x == 'None'): return 0
        else: return 1

# tags = list(set(e.tag for e in sum(relationships,[]))) + ['None'] # ids --> string tag
reversed_tags = Binary_Tag() # string tag --> ids
entity_tags = list(set(e.tag for e in sum(entities,[]))) 

def tok(text1, text2):
    # longest entity is 36 tokens long
    res = tokenizer.encode_plus(text1, text2,
                      max_length = MAX_LENGTH,
                      pad_to_max_length = True,
                      return_tensors = 'pt',
                      )
    return res['input_ids'][0], res['attention_mask'][0], res['token_type_ids'][0]
    
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, folder):
        texts, entities, relationships, filenames = read_files(folder)
        
        pre_dataset = []

        for text_id in range(len(texts)):
            relationships_nested = {(e.arg1, e.arg2):e for e in relationships[text_id] if is_nested(e)}
            nes = []
            for i in range(len(entities[text_id])):
                # O(n^2) eeeeeeeeee
                for j in range(i+1, len(entities[text_id])):
                    if (is_nested_anns2(entities[text_id][i], entities[text_id][j])):
                        nes.append((entities[text_id][i], entities[text_id][j]))
            for e in nes:
                if (e in relationships_nested):
                    pre_dataset.append((*e, relationships_nested[e].tag, text_id))
                elif ((e[1], e[0]) in relationships_nested):
                    pre_dataset.append((e[1], e[0], relationships_nested[(e[1], e[0])].tag, text_id))
                else:
                    pre_dataset.append((*e, 'None', text_id))

#         random.seed(2021)
        data = []
        for e1, e2, tag, text_id in tqdm(pre_dataset):
            
            data.append((reversed_tags[tag], entity_tags.index(e1.tag), entity_tags.index(e2.tag), tag, *tok(e1.text, e2.text)))
        
        self.data = data
    
    def __getitem__(self, index):
        return self.data[index]
    
    def __len__(self):
        return len(self.data)

# %%
#!g1.1
train_data = MyDataset('NEREL/NEREL-v1.0/train')
train_dl = DataLoader(train_data, shuffle=True, batch_size=32)

dev_data = MyDataset('NEREL/NEREL-v1.0/dev')
dev_dl = DataLoader(dev_data, batch_size=32)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=745.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=11175.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=93.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1301.0), HTML(value='')))
# incorrect format in: row=По словам очевидцев пешехо
#  file=21013_text

# %%
#!g1.1
next(iter(dev_dl))[1]
# Out:
# tensor([10, 10, 10, 10, 14, 14, 14, 14, 14, 14, 10, 10,  2, 26, 21, 13,  0,  0,
#         14, 14, 14, 24, 22,  5, 10, 10, 10, 10, 20, 20, 20, 10])

# %%
#!g1.1
next(iter(dev_dl))[1].size()
# Out:
# torch.Size([32])

# %% [markdown]
# # Training

# %%
#!g1.1
from transformers import BertTokenizer, BertModel
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.bert = BertModel.from_pretrained(
            "DeepPavlov/rubert-base-cased-sentence", # Use the 12-layer BERT model, with an uncased vocab.
            output_attentions = False, # Whether the model returns attentions weights.
            output_hidden_states = False, # Whether the model returns all hidden-states.
            max_length = MAX_LENGTH
            )
        self.dropout = nn.Dropout(0.1)
        self.emb = nn.Embedding(29, 10)
        self.fc = nn.Sequential(
            nn.Linear(768 + 10*2, 2),
#             nn.LeakyReLU(True),
#             nn.Linear(100, 1)
            )
        
    def forward(self, ent1, ent2, input_ids, attention_mask, token_type_ids, labels):
        ent1 = self.emb(ent1)
        ent2 = self.emb(ent2)
        out = self.bert(input_ids = input_ids, token_type_ids = token_type_ids, attention_mask = attention_mask)[1]
        out = self.dropout(out)
        out = torch.cat((out, ent1, ent2), dim=1)
        out = self.fc(out)
        criterion = nn.CrossEntropyLoss()
        loss = criterion(out.view(-1, 2), labels.view(-1))
        return loss, out
    
        # requires reconfiguration of hyper parameters
#         criterion = nn.BCEWithLogitsLoss()
#         out = self.fc(out).view(-1)
#         loss = criterion(out, labels)
#         return loss, torch.stack((-torch.sigmoid(out), torch.sigmoid(out)), dim = 1)

# %%
#!g1.1
model = MyModel()
model.to(device)
# Out:
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=642.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=711456784.0), HTML(value='')))
# MyModel(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(119547, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (emb): Embedding(29, 10)
#   (fc): Sequential(
#     (0): Linear(in_features=788, out_features=2, bias=True)
#   )
# )

# %%
#!g1.1
def calculate_accuracy(y_pred, y):
    return sum(torch.argmax(y_pred, axis = 1) == y)*1.0/len(y)

def train():
    model.train()
    running_loss = 0
    epoch_accuracy = 0

    pbar = tqdm(enumerate(train_dl), total = len(train_dl))
    for i, (labels, tag1, tag2, true_tag, input_ids, attention_mask, token_type_ids) in pbar:
        
        labels = labels.to(device)
        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        token_type_ids = token_type_ids.to(device)
        tag1 = tag1.to(device)
        tag2 = tag2.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(tag1, tag2,
                    input_ids, 
                    token_type_ids=token_type_ids,
                    attention_mask=attention_mask, 
                    labels=labels)
        
        loss = outputs[0]
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        epoch_accuracy += calculate_accuracy(outputs[1], labels).item()
        running_loss += loss.item()
        pbar.set_description(f'training: running_loss = {running_loss/(i+1.0):.4f} accuracy = {epoch_accuracy/(i+1.0):.4f},')
    
    scheduler.step(running_loss/(i+1))
    print(f'train loss= {running_loss/(i+1):.4f} \n train accuracy = {epoch_accuracy/(i+1):.4f},')

    
from sklearn.metrics import f1_score
def test():
    with torch.no_grad():
        model.eval()
        running_loss = 0
        epoch_accuracy = 0

#         dev_dl = DataLoader( MyDataset('NEREL/NEREL-v1.0/train'), batch_size = 32)

        pbar = tqdm(enumerate(dev_dl), total = len(dev_dl))

        y_true = []
        y_pred = []

        for i, (labels, tag1, tag2, true_tag, input_ids, attention_mask, token_type_ids) in pbar:
            labels = labels.to(device)
            input_ids = input_ids.to(device)
            attention_mask = attention_mask.to(device)
            token_type_ids = token_type_ids.to(device)
            tag1 = tag1.to(device)
            tag2 = tag2.to(device)

            outputs = model(tag1, tag2,
                        input_ids, 
                        token_type_ids=token_type_ids,
                        attention_mask=attention_mask, 
                        labels=labels)

            loss = outputs[0]
#             calculate_accuracy(outputs[1], labels)
            y_true += [e.item() for e in labels]
            y_pred += [e.item() for e in torch.argmax(outputs[1], axis = 1)]
            
            running_loss += loss.item()
            epoch_accuracy += calculate_accuracy(outputs[1], labels).item()
            # pbar.set_description(f'testing: running_loss = {running_loss/(i+1):.4f} accuracy = {epoch_accuracy/(i+1):.4f},')
#     print(y_true, y_pred)
    print(f'test loss= {running_loss/(i+1):.4f} \n test accuracy = {epoch_accuracy/(i+1):.4f}, F1 = {f1_score(y_true, y_pred)}')

# %%
#!g1.1
optimizer = torch.optim.AdamW(model.parameters(),
                  lr = 5e-5, # args.learning_rate 
                  eps = 5e-8#1e-8 # args.adam_epsilon 
                )
scheduler = ReduceLROnPlateau(optimizer, patience = 3, cooldown = 1, factor = 0.5)

# %%
#!g1.1
seed_val = 2021

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)
for epoch in range(1, 21):
    print(f'epoch = {epoch}')
    print('lr=', optimizer.param_groups[0]['lr'])
    train()
    test()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=350.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=41.0), HTML(value='')))
# epoch = 1
# lr= 5e-05
#
# train loss= 0.3268
#  train accuracy = 0.8613,
#
# test loss= 0.3031
#  test accuracy = 0.8803, F1 = 0.84765625
# epoch = 2
# lr= 5e-05
#
# train loss= 0.2075
#  train accuracy = 0.9230,
#
# test loss= 0.3264
#  test accuracy = 0.8807, F1 = 0.8300653594771241
# epoch = 3
# lr= 5e-05
#
# train loss= 0.1675
#  train accuracy = 0.9404,
#
# test loss= 0.3159
#  test accuracy = 0.8929, F1 = 0.8574338085539714
# epoch = 4
# lr= 5e-05
#
# train loss= 0.1388
#  train accuracy = 0.9542,
#
# test loss= 0.4460
#  test accuracy = 0.8819, F1 = 0.8345784418356457
# epoch = 5
# lr= 5e-05
#
# train loss= 0.1208
#  train accuracy = 0.9615,
#
# test loss= 0.3586
#  test accuracy = 0.8910, F1 = 0.8493150684931507
# epoch = 6
# lr= 5e-05
#
# train loss= 0.1018
#  train accuracy = 0.9676,
#
# test loss= 0.6063
#  test accuracy = 0.8754, F1 = 0.8394088669950739
# epoch = 7
# lr= 5e-05
#
# train loss= 0.0875
#  train accuracy = 0.9721,
#
# test loss= 0.5806
#  test accuracy = 0.8834, F1 = 0.8474576271186441
# epoch = 8
# lr= 5e-05
#
# train loss= 0.0798
#  train accuracy = 0.9752,
#
# test loss= 0.5567
#  test accuracy = 0.8883, F1 = 0.8475991649269311
# epoch = 9
# lr= 5e-05
#
# train loss= 0.0835
#  train accuracy = 0.9763,
#
# test loss= 0.4462
#  test accuracy = 0.8891, F1 = 0.8500517063081696
# epoch = 10
# lr= 5e-05
#
# train loss= 0.0841
#  train accuracy = 0.9757,
#
# test loss= 0.5051
#  test accuracy = 0.8791, F1 = 0.8389743589743589
# epoch = 11
# lr= 5e-05
#
# train loss= 0.0750
#  train accuracy = 0.9793,
#
# test loss= 0.5415
#  test accuracy = 0.8822, F1 = 0.8478260869565217
# epoch = 12
# lr= 5e-05
#
# train loss= 0.0647
#  train accuracy = 0.9817,
#
# test loss= 0.6588
#  test accuracy = 0.8784, F1 = 0.8411588411588412
# epoch = 13
# lr= 5e-05
#
# train loss= 0.0732
#  train accuracy = 0.9794,
#
# test loss= 0.4661
#  test accuracy = 0.8876, F1 = 0.8528528528528528
# epoch = 14
# lr= 5e-05
#
# train loss= 0.0661
#  train accuracy = 0.9825,
#
# test loss= 0.5548
#  test accuracy = 0.8765, F1 = 0.8444444444444444
# epoch = 15
# lr= 5e-05
#
# train loss= 0.0644
#  train accuracy = 0.9819,
#
# test loss= 0.5716
#  test accuracy = 0.8826, F1 = 0.844758064516129
# epoch = 16
# lr= 5e-05
#
# train loss= 0.0580
#  train accuracy = 0.9829,
#
# test loss= 0.5670
#  test accuracy = 0.8788, F1 = 0.8423153692614771
# epoch = 17
# lr= 5e-05
#
# train loss= 0.0546
#  train accuracy = 0.9847,
#
# test loss= 0.5328
#  test accuracy = 0.8807, F1 = 0.8433734939759036
# epoch = 18
# lr= 5e-05
#
# train loss= 0.0521
#  train accuracy = 0.9857,
#
# test loss= 0.7126
#  test accuracy = 0.8761, F1 = 0.8408644400785854
# epoch = 19
# lr= 5e-05
#
# train loss= 0.0497
#  train accuracy = 0.9878,
#
# test loss= 0.6818
#  test accuracy = 0.8769, F1 = 0.8338493292053665
# epoch = 20
# lr= 5e-05
#
# train loss= 0.0453
#  train accuracy = 0.9868,
#
# test loss= 0.6091
#  test accuracy = 0.8815, F1 = 0.8416751787538304

# %%
#!g1.1
torch.save(model.state_dict(), 'models/Set2_BERT_Binary_tags')

# %%
#!g1.1
with torch.no_grad():
    model.eval()
    running_loss = 0
    epoch_accuracy = 0

    dev_dl = DataLoader( MyDataset('NEREL/NEREL-v1.0/dev'), batch_size = 1)

    pbar = tqdm(enumerate(dev_dl), total = len(dev_dl))

    y_true = []
    y_pred = []
    tags = []

    for i, (labels, tag1, tag2, true_tag, input_ids, attention_mask, token_type_ids) in pbar:
        labels = labels.to(device)
        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        token_type_ids = token_type_ids.to(device)
        tag1 = tag1.to(device)
        tag2 = tag2.to(device)

        outputs = model(tag1, tag2,
                        input_ids, 
                        token_type_ids=token_type_ids,
                        attention_mask=attention_mask, 
                        labels=labels)

        loss = outputs[0]
#             calculate_accuracy(outputs[1], labels)
        y_true += [e.item() for e in labels]
        y_pred += [e.item() for e in torch.argmax(outputs[1], axis = 1)]
        tags += [(tag1, tag2)]
        
        running_loss += loss.item()
        epoch_accuracy += calculate_accuracy(outputs[1], labels).item()
        if (torch.argmax(outputs[1], axis = 1) != labels):
            print('expected:', labels.detach().cpu().item())
            print('found:', torch.argmax(outputs[1], axis = 1).detach().cpu().item(), '(', outputs[1].detach().cpu().numpy() ,')')
            print(f'{entity_tags[tag1[0]]} ---> {entity_tags[tag2[0]]} : {true_tag[0]}')
            print(tokenizer.decode(input_ids[0].detach().cpu().numpy()).replace(r'[PAD]', ''))
            print()
            
print(f'test loss= {running_loss/(i+1):.4f} \n test accuracy = {epoch_accuracy/(i+1):.4f}, F1 = {f1_score(y_true, y_pred)}')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=93.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1301.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1301.0), HTML(value='')))
# expected: 0
# found: 1 ( [[-2.4710145  1.46265  ]] )
# PROFESSION ---> EVENT : None
# [CLS] главным менеджером Международного музыкального фестиваля « Ереванские перспективы » [SEP] Ереванские перспективы [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9889588 -3.1045446]] )
# PROFESSION ---> COUNTRY : ORIGINS_FROM
# [CLS] сотрудников исправительных учреждений Италии [SEP] Италии [SEP]
#
# expected: 0
# found: 1 ( [[-3.052774  1.931249]] )
# PROFESSION ---> COUNTRY : None
# [CLS] Премьер - министр Великобритании [SEP] Великобритании [SEP]
#
# expected: 1
# found: 0 ( [[ 1.8542894 -1.2165093]] )
# PROFESSION ---> ORGANIZATION : WORKPLACE
# [CLS] Гендиректор ООО УК « Металлоинвест [SEP] Металлоинвест [SEP]
#
# expected: 0
# found: 1 ( [[-2.0116355   0.98010147]] )
# EVENT ---> DISEASE : None
# [CLS] пандемию COVID - 19 [SEP] COVID - 19 [SEP]
#
# expected: 0
# found: 1 ( [[-2.864251   1.7322389]] )
# ORGANIZATION ---> COUNTRY : None
# [CLS] Гегаркуникском областном следственном управлении Следственного комитета Армении [SEP] Армении [SEP]
#
# expected: 0
# found: 1 ( [[-2.9589612  1.8201842]] )
# LAW ---> LAW : None
# [CLS] части 2 статьи 34 - 104 [SEP] статьи 34 - 104 [SEP]
#
# expected: 1
# found: 0 ( [[ 2.412328  -1.5389035]] )
# LAW ---> DATE : DATE_OF_CREATION
# [CLS] декларации Организации Объединенных Наций 1942 года [SEP] 1942 года [SEP]
#
# expected: 1
# found: 0 ( [[ 0.58205956 -0.24960975]] )
# ORGANIZATION ---> COUNTRY : HEADQUARTERED_IN
# [CLS] 1 - го Украинского фронта СССР [SEP] СССР [SEP]
#
# expected: 0
# found: 1 ( [[-2.1803212  1.3265072]] )
# EVENT ---> EVENT : None
# [CLS] празднования юбилея встречи на Эльбе [SEP] встречи на Эльбе [SEP]
#
# expected: 0
# found: 1 ( [[-2.2516272  1.3465656]] )
# DISEASE ---> DISEASE : None
# [CLS] коронавирусу SARS - CoV - 2 [SEP] SARS - CoV - 2 [SEP]
#
# expected: 1
# found: 0 ( [[ 4.0087137 -2.98638  ]] )
# LAW ---> COUNTRY : ORIGINS_FROM
# [CLS] Федеральному закону « О внесении изменений в отдельные законодательные акты Российской Федерации по вопросам назначения и выплаты пенсий » [SEP] Российской Федерации [SEP]
#
# expected: 1
# found: 0 ( [[ 4.1366353 -3.5406067]] )
# ORGANIZATION ---> PERSON : FOUNDED_BY
# [CLS] Правительство Медведева [SEP] Медведева [SEP]
#
# expected: 0
# found: 1 ( [[-1.3706169   0.10722429]] )
# LAW ---> STATE_OR_PROVINCE : None
# [CLS] Конституции штата Колорадо пункт 26 статьи 2 [SEP] Колорадо [SEP]
#
# expected: 1
# found: 0 ( [[ 2.9817781 -2.1399746]] )
# LAW ---> LAW : PART_OF
# [CLS] О внесении изменения в статью 128. 1 Уголовного кодекса Российской Федерации [SEP] статью 128. 1 Уголовного кодекса Российской Федерации [SEP]
#
# expected: 1
# found: 0 ( [[ 2.421317  -1.6177429]] )
# ORGANIZATION ---> PRODUCT : ABBREVIATION
# [CLS] Яндекс [SEP] Яндекс. Новостях [SEP]
#
# expected: 1
# found: 0 ( [[ 1.8088342 -1.0452791]] )
# LAW ---> LAW : PART_OF
# [CLS] статьи 128. 1 УК РФ « Клевета » [SEP] УК РФ [SEP]
#
# expected: 1
# found: 0 ( [[ 4.0054913 -3.3760147]] )
# PROFESSION ---> LOCATION : WORKPLACE
# [CLS] руководителя Приволжского межрегионального координационного совета « Единой России » [SEP] Приволжского [SEP]
#
# expected: 0
# found: 1 ( [[-3.1683593  1.8553723]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] руководителя Приволжского межрегионального координационного совета « Единой России » [SEP] Приволжского межрегионального координационного совета « Единой России » [SEP]
#
# expected: 0
# found: 1 ( [[-2.882293   1.5716276]] )
# ORGANIZATION ---> ORGANIZATION : None
# [CLS] Приволжского межрегионального координационного совета « Единой России » [SEP] Единой России [SEP]
#
# expected: 0
# found: 1 ( [[-2.3538873  1.3372247]] )
# LAW ---> COUNTRY : None
# [CLS] Алексеев и другие против России [SEP] России [SEP]
#
# expected: 0
# found: 1 ( [[-2.3538873  1.3372247]] )
# LAW ---> COUNTRY : None
# [CLS] Алексеев и другие против России [SEP] России [SEP]
#
# expected: 0
# found: 1 ( [[-3.1945703  1.8433557]] )
# PROFESSION ---> PROFESSION : None
# [CLS] заместителем генпрокурора [SEP] генпрокурора [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9555085 -3.1965373]] )
# PROFESSION ---> RELIGION : RELIGION_OF
# [CLS] лидеров Католичеcкой церкви [SEP] Католичеcкой [SEP]
#
# expected: 1
# found: 0 ( [[ 2.78463   -2.1523118]] )
# PROFESSION ---> PROFESSION : SUBORDINATE_OF
# [CLS] ассистентку стоматолога [SEP] стоматолога [SEP]
#
# expected: 0
# found: 1 ( [[-2.2103705  1.1527712]] )
# PENALTY ---> MONEY : None
# [CLS] штраф в 5000 рублей [SEP] 5000 рублей [SEP]
#
# expected: 0
# found: 1 ( [[-3.0398216  1.8968946]] )
# PENALTY ---> MONEY : None
# [CLS] административного штрафа в размере от 3 до 5 тысяч рублей [SEP] от 3 до 5 тысяч рублей [SEP]
#
# expected: 1
# found: 0 ( [[ 4.1478653 -3.269668 ]] )
# PROFESSION ---> EVENT : WORKPLACE
# [CLS] главным советником избирательной кампании Бориса Ельцина [SEP] избирательной кампании [SEP]
#
# expected: 1
# found: 0 ( [[ 4.1163344 -3.6329954]] )
# PROFESSION ---> PROFESSION : SUBORDINATE_OF
# [CLS] главой предвыборного штаба телеведущей Ксении Собчак [SEP] телеведущей [SEP]
#
# expected: 1
# found: 0 ( [[ 4.2103024 -3.20108  ]] )
# PROFESSION ---> COUNTRY : WORKPLACE
# [CLS] президенты России [SEP] России [SEP]
#
# expected: 0
# found: 1 ( [[-3.1057942  1.8120486]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] Вокалист британской группы The Prodigy [SEP] The Prodigy [SEP]
#
# expected: 0
# found: 1 ( [[-2.6757677  1.3263719]] )
# PROFESSION ---> CITY : None
# [CLS] Главу одного из пяти крупнейших мафиозных кланов Нью - Йорка [SEP] Нью - Йорка [SEP]
#
# expected: 1
# found: 0 ( [[ 4.0569396 -3.271908 ]] )
# PROFESSION ---> ORGANIZATION : WORKPLACE
# [CLS] главарем клана Гамбино [SEP] Гамбино [SEP]
#
# expected: 0
# found: 1 ( [[-2.930772   1.5688094]] )
# ORGANIZATION ---> PROFESSION : None
# [CLS] Суд присяжных [SEP] присяжных [SEP]
#
# expected: 0
# found: 1 ( [[-2.8488314  1.9051322]] )
# EVENT ---> EVENT : None
# [CLS] XXVII фестиваля « Кинотавр [SEP] Кинотавр [SEP]
#
# expected: 0
# found: 1 ( [[-3.1893299  1.8716549]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] председателем Регионального отделения РФСХ Республики Башкортостан [SEP] Регионального отделения РФСХ Республики Башкортостан [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9821959 -3.4741724]] )
# ORGANIZATION ---> ORGANIZATION : PART_OF
# [CLS] Регионального отделения РФСХ Республики Башкортостан [SEP] РФСХ [SEP]
#
# expected: 1
# found: 0 ( [[ 3.0723073 -2.3913913]] )
# ORGANIZATION ---> STATE_OR_PROVINCE : HEADQUARTERED_IN
# [CLS] Регионального отделения РФСХ Республики Башкортостан [SEP] Республики Башкортостан [SEP]
#
# expected: 0
# found: 1 ( [[-2.4118958  1.201433 ]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] главы Администрации Советского района Уфы [SEP] Администрации Советского района Уфы [SEP]
#
# expected: 1
# found: 0 ( [[ 3.961982  -3.1885552]] )
# ORGANIZATION ---> DISTRICT : HEADQUARTERED_IN
# [CLS] Администрации Советского района Уфы [SEP] Советского района [SEP]
#
# expected: 1
# found: 0 ( [[ 0.39671957 -0.4120897 ]] )
# ORGANIZATION ---> CITY : HEADQUARTERED_IN
# [CLS] Эхо Москвы [SEP] Москвы [SEP]
#
# expected: 0
# found: 1 ( [[-3.1464248  1.8399489]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] Главред радио « Эхо Москвы [SEP] Эхо Москвы [SEP]
#
# expected: 1
# found: 0 ( [[ 0.39671957 -0.4120897 ]] )
# ORGANIZATION ---> CITY : HEADQUARTERED_IN
# [CLS] Эхо Москвы [SEP] Москвы [SEP]
#
# expected: 1
# found: 0 ( [[ 2.6908448 -1.7881026]] )
# PROFESSION ---> COUNTRY : WORKPLACE
# [CLS] президент Перу [SEP] Перу [SEP]
#
# expected: 1
# found: 0 ( [[ 2.6908448 -1.7881026]] )
# PROFESSION ---> COUNTRY : WORKPLACE
# [CLS] президент Перу [SEP] Перу [SEP]
#
# expected: 1
# found: 0 ( [[ 2.6908448 -1.7881026]] )
# PROFESSION ---> COUNTRY : WORKPLACE
# [CLS] президент Перу [SEP] Перу [SEP]
#
# expected: 1
# found: 0 ( [[ 3.3435156 -2.3514197]] )
# PROFESSION ---> COUNTRY : WORKPLACE
# [CLS] президента Перу [SEP] Перу [SEP]
#
# expected: 1
# found: 0 ( [[ 1.6420115 -1.0850248]] )
# EVENT ---> CITY : TAKES_PLACE_IN
# [CLS] Олимпиады в Рио в 2016 году [SEP] Рио [SEP]
#
# expected: 0
# found: 1 ( [[-3.3453524  1.9508399]] )
# ORGANIZATION ---> ORGANIZATION : None
# [CLS] Главном управлении Нацполиции [SEP] Нацполиции [SEP]
#
# expected: 1
# found: 0 ( [[ 3.957729  -3.3981261]] )
# ORGANIZATION ---> ORGANIZATION : PART_OF
# [CLS] Главном управлении Нацполиции по Кировоградской области [SEP] Нацполиции [SEP]
#
# expected: 1
# found: 0 ( [[ 1.6802988 -1.2008574]] )
# ORGANIZATION ---> STATE_OR_PROVINCE : HEADQUARTERED_IN
# [CLS] Главном управлении Нацполиции по Кировоградской области [SEP] Кировоградской области [SEP]
#
# expected: 0
# found: 1 ( [[-3.0439973  1.9535577]] )
# FACILITY ---> DISTRICT : None
# [CLS] синагоге Сан - Диего [SEP] Сан - Диего [SEP]
#
# expected: 0
# found: 1 ( [[-3.1821988  1.8659574]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] Шеф полиции [SEP] полиции [SEP]
#
# expected: 1
# found: 0 ( [[ 3.8903968 -3.5406954]] )
# ORGANIZATION ---> STATE_OR_PROVINCE : HEADQUARTERED_IN
# [CLS] филиала университета штата Калифорния в городе Сан - Маркос [SEP] Калифорния [SEP]
#
# expected: 0
# found: 1 ( [[-2.846333   1.4339349]] )
# ORGANIZATION ---> STATE_OR_PROVINCE : None
# [CLS] университета штата Калифорния [SEP] Калифорния [SEP]
#
# expected: 0
# found: 1 ( [[-2.7879417  1.6917737]] )
# FACILITY ---> PERSON : None
# [CLS] святилище богини Аматэрасу [SEP] Аматэрасу [SEP]
#
# expected: 0
# found: 1 ( [[-3.087538   1.9230405]] )
# FACILITY ---> PERSON : None
# [CLS] главный храм Аматэрасу [SEP] Аматэрасу [SEP]
#
# expected: 1
# found: 0 ( [[ 3.872871  -3.2198384]] )
# ORGANIZATION ---> ORGANIZATION : PART_OF
# [CLS] Главное управление МВД России по Нижегородской области [SEP] МВД России [SEP]
#
# expected: 1
# found: 0 ( [[ 2.4158602 -1.7632617]] )
# ORGANIZATION ---> STATE_OR_PROVINCE : HEADQUARTERED_IN
# [CLS] Главное управление МВД России по Нижегородской области [SEP] Нижегородской области [SEP]
#
# expected: 0
# found: 1 ( [[-1.2458737   0.24002673]] )
# EVENT ---> WORK_OF_ART : None
# [CLS] финале « Голос. Дети [SEP] Голос. Дети [SEP]
#
# expected: 0
# found: 1 ( [[-2.758248  1.6506  ]] )
# EVENT ---> WORK_OF_ART : None
# [CLS] финальное шоу « Голос. Дети [SEP] Голос. Дети [SEP]
#
# expected: 1
# found: 0 ( [[ 3.8372352 -3.142489 ]] )
# PROFESSION ---> STATE_OR_PROVINCE : ORIGINS_FROM
# [CLS] члена Совета Федерации от Республики Алтай [SEP] Республики Алтай [SEP]
#
# expected: 1
# found: 0 ( [[ 4.4425063 -3.4572692]] )
# EVENT ---> PERSON : ORIGINS_FROM
# [CLS] Международного конкурса имени Петра Чайковского [SEP] Петра Чайковского [SEP]
#
# expected: 1
# found: 0 ( [[ 3.2781978 -2.005723 ]] )
# EVENT ---> EVENT : SUBEVENT_OF
# [CLS] XXVII Музыкальному фестивалю « Звёзды белых ночей [SEP] Звёзды белых ночей [SEP]
#
# expected: 1
# found: 0 ( [[ 4.4352884 -3.5129046]] )
# EVENT ---> PERSON : ORIGINS_FROM
# [CLS] Конкурса имени Чайковского [SEP] Чайковского [SEP]
#
# expected: 1
# found: 0 ( [[ 4.063542  -3.1736734]] )
# WORK_OF_ART ---> PERSON : ORIGINS_FROM
# [CLS] Один день Ивана Денисовича [SEP] Ивана Денисовича [SEP]
#
# expected: 0
# found: 1 ( [[-2.9677503  1.9887176]] )
# EVENT ---> EVENT : None
# [CLS] 21 кинофестивале « Кинотавр [SEP] Кинотавр [SEP]
#
# expected: 1
# found: 0 ( [[ 4.063542  -3.1736734]] )
# WORK_OF_ART ---> PERSON : ORIGINS_FROM
# [CLS] Один день Ивана Денисовича [SEP] Ивана Денисовича [SEP]
#
# expected: 1
# found: 0 ( [[ 4.063542  -3.1736734]] )
# WORK_OF_ART ---> PERSON : ORIGINS_FROM
# [CLS] Один день Ивана Денисовича [SEP] Ивана Денисовича [SEP]
#
# expected: 0
# found: 1 ( [[-3.1389594  1.8344401]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] начальника Управления по контролю за оборотом наркотиков Главного управления МВД по Москве [SEP] Главного управления МВД по Москве [SEP]
#
# expected: 0
# found: 1 ( [[-2.1553955   0.74790245]] )
# ORGANIZATION ---> CITY : None
# [CLS] Управления по контролю за оборотом наркотиков Главного управления МВД по Москве [SEP] Москве [SEP]
#
# expected: 1
# found: 0 ( [[ 3.8537254 -3.1285305]] )
# ORGANIZATION ---> ORGANIZATION : PART_OF
# [CLS] Главного управления МВД по Москве [SEP] МВД [SEP]
#
# expected: 1
# found: 0 ( [[ 1.1249287 -1.1480263]] )
# ORGANIZATION ---> CITY : HEADQUARTERED_IN
# [CLS] Главного управления МВД по Москве [SEP] Москве [SEP]
#
# expected: 0
# found: 1 ( [[-3.299625  2.055968]] )
# ORGANIZATION ---> DISTRICT : None
# [CLS] полиции Западного административного округа Москвы [SEP] Западного административного округа [SEP]
#
# expected: 1
# found: 0 ( [[ 3.3169312 -2.5738537]] )
# PROFESSION ---> ORGANIZATION : WORKPLACE
# [CLS] зампредседателя Госсовета [SEP] Госсовета [SEP]
#
# expected: 1
# found: 0 ( [[ 4.491703  -3.5977147]] )
# EVENT ---> EVENT : HAS_CAUSE
# [CLS] подавлял протесты [SEP] протесты [SEP]
#
# expected: 1
# found: 0 ( [[ 3.949148  -3.4436383]] )
# ORGANIZATION ---> ORGANIZATION : PART_OF
# [CLS] штаба ВМС в Южно - Китайском море [SEP] ВМС [SEP]
#
# expected: 1
# found: 0 ( [[ 4.000498  -3.0148463]] )
# LAW ---> LAW : PART_OF
# [CLS] ст. 20. 2 КоАП [SEP] КоАП [SEP]
#
# expected: 0
# found: 1 ( [[-3.2563875  2.047364 ]] )
# ORGANIZATION ---> COUNTRY : None
# [CLS] Суд в Италии [SEP] Италии [SEP]
#
# expected: 0
# found: 1 ( [[-1.5448064   0.15729678]] )
# LOCATION ---> CITY : None
# [CLS] вблизи Славянска [SEP] Славянска [SEP]
#
# expected: 0
# found: 1 ( [[-3.5108914  1.9696466]] )
# ORGANIZATION ---> CITY : None
# [CLS] Итальянская прокуратура города Павия [SEP] Павия [SEP]
#
# expected: 1
# found: 0 ( [[ 3.8769107 -2.9283357]] )
# PERSON ---> WORK_OF_ART : PRODUCES
# [CLS] Александр Ширвиндт [SEP] Александр Ширвиндт : „ Ирония спасает от всего “ [SEP]
#
# expected: 1
# found: 0 ( [[ 4.0049314 -2.9672444]] )
# EVENT ---> LOCATION : TAKES_PLACE_IN
# [CLS] пересечению Ла - Манш [SEP] Ла - Манш [SEP]
#
# expected: 1
# found: 0 ( [[ 4.1288033 -3.120966 ]] )
# EVENT ---> LOCATION : TAKES_PLACE_IN
# [CLS] перелета через Ла - Манш [SEP] Ла - Манш [SEP]
#
# expected: 1
# found: 0 ( [[ 3.6756017 -2.7179527]] )
# EVENT ---> FACILITY : TAKES_PLACE_IN
# [CLS] расправы на площади Тянаньмэнь [SEP] площади Тянаньмэнь [SEP]
#
# expected: 1
# found: 0 ( [[ 4.2396817 -3.3399885]] )
# PROFESSION ---> COUNTRY : WORKPLACE
# [CLS] премьер Государственного совета Китая [SEP] Китая [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9831626 -2.6388392]] )
# EVENT ---> COUNTRY : TAKES_PLACE_IN
# [CLS] XXI Всероссийский Шукшинский кинофестиваль [SEP] Всероссийский [SEP]
#
# expected: 0
# found: 1 ( [[-1.8181287  1.0223657]] )
# EVENT ---> EVENT : None
# [CLS] Всероссийского фестиваля « Шукшинские дни на Алтае [SEP] Шукшинские дни на Алтае [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9435697 -2.9585721]] )
# FACILITY ---> PERSON : ORIGINS_FROM
# [CLS] памятника Василию Шукшину [SEP] Василию Шукшину [SEP]
#
# expected: 1
# found: 0 ( [[ 3.3150947 -2.5892253]] )
# PROFESSION ---> FACILITY : WORKPLACE
# [CLS] настоятель собора во имя святого благоверного и великого князя Александра Невского [SEP] собора во имя святого благоверного и великого князя Александра Невского [SEP]
#
# expected: 0
# found: 1 ( [[-1.8638661   0.99443567]] )
# EVENT ---> PERSON : None
# [CLS] литературных мероприятиях « Шукшинских дней на Алтае » [SEP] Шукшинских [SEP]
#
# expected: 1
# found: 0 ( [[ 4.329099 -3.472545]] )
# FACILITY ---> PERSON : ORIGINS_FROM
# [CLS] Алтайского краевого театра драмы им. В. М. Шукшина [SEP] В. М. Шукшина [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9383001 -2.9607995]] )
# PERSON ---> ORGANIZATION : WORKPLACE
# [CLS] Любови Соболь [SEP] штаб Любови Соболь и Ивана Жданова [SEP]
#
# expected: 1
# found: 0 ( [[ 3.635083 -2.590441]] )
# PERSON ---> ORGANIZATION : WORKPLACE
# [CLS] Любови Соболь [SEP] штаб Любови Соболь и Ивана Жданов [SEP]
#
# expected: 1
# found: 0 ( [[ 4.379908  -3.5482404]] )
# EVENT ---> ORGANIZATION : TAKES_PLACE_IN
# [CLS] пошли к мэрии [SEP] мэрии [SEP]
#
# expected: 1
# found: 0 ( [[ 3.955714 -2.964021]] )
# LAW ---> LAW : PART_OF
# [CLS] ст. 141 УК [SEP] УК [SEP]
#
# expected: 1
# found: 0 ( [[ 4.4344144 -3.3333235]] )
# EVENT ---> COUNTRY : TAKES_PLACE_IN
# [CLS] войны в Ираке [SEP] Ираке [SEP]
#
# expected: 1
# found: 0 ( [[ 4.442802  -3.5893195]] )
# PERSON ---> COUNTRY : WORKPLACE
# [CLS] наследника британской короны [SEP] британской [SEP]
#
# expected: 0
# found: 1 ( [[-3.0460443  1.8125141]] )
# PERSON ---> FAMILY : None
# [CLS] герцогиня Корнуольская [SEP] Корнуольская [SEP]
#
# expected: 0
# found: 1 ( [[-3.124324   1.9519452]] )
# ORGANIZATION ---> COUNTRY : None
# [CLS] Национальной системы здравоохранения Великобритании [SEP] Великобритании [SEP]
#
# expected: 0
# found: 1 ( [[-3.1581953  1.8480762]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] президент Института Пушкина [SEP] Института Пушкина [SEP]
#
# expected: 1
# found: 0 ( [[ 3.1479068 -2.2664115]] )
# ORGANIZATION ---> ORGANIZATION : PART_OF
# [CLS] переводческого факультета московского Института иностранных языков имени М. Тореза [SEP] Института иностранных языков имени М. Тореза [SEP]
#
# expected: 0
# found: 1 ( [[-2.5399525  1.2518182]] )
# ORGANIZATION ---> ORGANIZATION : None
# [CLS] Института языкознания АН СССР [SEP] АН СССР [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9524512 -3.1325815]] )
# ORGANIZATION ---> COUNTRY : HEADQUARTERED_IN
# [CLS] Института языкознания АН СССР [SEP] СССР [SEP]
#
# expected: 0
# found: 1 ( [[-2.9585016  1.6967143]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] президентом Международной ассоциации преподавателей русского языка и литературы [SEP] Международной ассоциации преподавателей русского языка и литературы [SEP]
#
# expected: 1
# found: 0 ( [[ 3.72211   -2.5857868]] )
# PROFESSION ---> COUNTRY : WORKPLACE
# [CLS] Президент Польши [SEP] Польши [SEP]
#
# expected: 0
# found: 1 ( [[-1.0703988  -0.08845453]] )
# WORK_OF_ART ---> CITY : None
# [CLS] Плач по жертвам Хиросимы [SEP] Хиросимы [SEP]
#
# expected: 1
# found: 0 ( [[ 1.9851655 -1.4548628]] )
# EVENT ---> CITY : TAKES_PLACE_IN
# [CLS] выступления гданьских докеров [SEP] гданьских [SEP]
#
# expected: 0
# found: 1 ( [[-2.5758982  1.2857281]] )
# WORK_OF_ART ---> CITY : None
# [CLS] Рукопись, найденная в Сарагосе [SEP] Сарагосе [SEP]
#
# expected: 1
# found: 0 ( [[ 3.7366095 -2.6372337]] )
# EVENT ---> LOCATION : TAKES_PLACE_IN
# [CLS] форсировании Днепра [SEP] Днепра [SEP]
#
# expected: 0
# found: 1 ( [[-2.5105777  1.567648 ]] )
# DISEASE ---> DISEASE : None
# [CLS] коронавируса SARS - CoV - 2 [SEP] SARS - CoV - 2 [SEP]
#
# expected: 1
# found: 0 ( [[ 1.8168193 -1.0973524]] )
# PROFESSION ---> LOCATION : WORKPLACE
# [CLS] министр финансов немецкой земли Гессен [SEP] Гессен [SEP]
#
# expected: 1
# found: 0 ( [[ 1.2747207 -1.3096722]] )
# EVENT ---> DISEASE : HAS_CAUSE
# [CLS] эпидемией коронавируса SARS - CoV - 2 [SEP] коронавируса SARS - CoV - 2 [SEP]
#
# expected: 0
# found: 1 ( [[-2.0563169  1.0360304]] )
# EVENT ---> DISEASE : None
# [CLS] эпидемией коронавируса SARS - CoV - 2 [SEP] SARS - CoV - 2 [SEP]
#
# expected: 0
# found: 1 ( [[-2.5105777  1.567648 ]] )
# DISEASE ---> DISEASE : None
# [CLS] коронавируса SARS - CoV - 2 [SEP] SARS - CoV - 2 [SEP]
#
# expected: 0
# found: 1 ( [[-2.8012025  1.7978086]] )
# DISEASE ---> DISEASE : None
# [CLS] коронавирусом SARS - CoV - 2 [SEP] SARS - CoV - 2 [SEP]
#
# expected: 0
# found: 1 ( [[-3.2081735  2.010013 ]] )
# FACILITY ---> LOCATION : None
# [CLS] больницу Санта Орсола [SEP] Санта Орсола [SEP]
#
# expected: 0
# found: 1 ( [[-3.1133254  1.8642188]] )
# FACILITY ---> ORGANIZATION : None
# [CLS] больницу Королевского колледжа Лондона [SEP] Королевского колледжа Лондона [SEP]
#
# expected: 1
# found: 0 ( [[ 3.5516374 -2.7939253]] )
# ORGANIZATION ---> CITY : HEADQUARTERED_IN
# [CLS] Королевского колледжа Лондона [SEP] Лондона [SEP]
#
# expected: 0
# found: 1 ( [[-3.3920264  1.8264047]] )
# LOCATION ---> CITY : None
# [CLS] юге Лондона [SEP] Лондона [SEP]
#
# expected: 0
# found: 1 ( [[-2.7103758  1.7252809]] )
# DISEASE ---> DISEASE : None
# [CLS] коронавирус SARS - CoV - 2 [SEP] SARS - CoV - 2 [SEP]
#
# expected: 0
# found: 1 ( [[-3.1900952  1.8724421]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] представитель NHS [SEP] NHS [SEP]
#
# expected: 0
# found: 1 ( [[-3.251988   2.0432394]] )
# ORGANIZATION ---> COUNTRY : None
# [CLS] Public Health England [SEP] England [SEP]
#
# expected: 0
# found: 1 ( [[-3.1126442  1.8721625]] )
# STATE_OR_PROVINCE ---> STATE_OR_PROVINCE : None
# [CLS] Республике Башкортостан [SEP] Башкортостан [SEP]
#
# expected: 0
# found: 1 ( [[-3.0620239  1.9120107]] )
# PENALTY ---> MONEY : None
# [CLS] штраф в размере 15 тысяч рублей [SEP] 15 тысяч рублей [SEP]
#
# expected: 0
# found: 1 ( [[-3.1129353  1.8164673]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] председатель Совета директоров « Башинформа [SEP] Совета директоров « Башинформа [SEP]
#
# expected: 1
# found: 0 ( [[ 3.7717593 -2.9386024]] )
# PROFESSION ---> ORGANIZATION : WORKPLACE
# [CLS] председатель Совета директоров « Башинформа [SEP] Башинформа [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9953156 -3.3557477]] )
# ORGANIZATION ---> RELIGION : RELIGION_OF
# [CLS] духовного управления мусульман Ингушетии [SEP] мусульман [SEP]
#
# expected: 0
# found: 1 ( [[-1.8488077  0.6465677]] )
# PROFESSION ---> PROFESSION : None
# [CLS] Временно исполняющий обязанности председателя правительства Ингушетии [SEP] председателя правительства Ингушетии [SEP]
#
# expected: 1
# found: 0 ( [[ 3.6748338 -2.935729 ]] )
# PROFESSION ---> STATE_OR_PROVINCE : WORKPLACE
# [CLS] Временно исполняющий обязанности председателя правительства Ингушетии [SEP] Ингушетии [SEP]
#
# expected: 0
# found: 1 ( [[-3.1245766  1.8245327]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] главой духовного управления мусульман Ингушетии [SEP] духовного управления мусульман Ингушетии [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9953156 -3.3557477]] )
# ORGANIZATION ---> RELIGION : RELIGION_OF
# [CLS] духовного управления мусульман Ингушетии [SEP] мусульман [SEP]
#
# expected: 1
# found: 0 ( [[ 1.5051321 -0.959688 ]] )
# ORGANIZATION ---> STATE_OR_PROVINCE : HEADQUARTERED_IN
# [CLS] духовного управления мусульман Ингушетии [SEP] Ингушетии [SEP]
#
# expected: 1
# found: 0 ( [[ 3.9344263 -3.1533158]] )
# PROFESSION ---> PROFESSION : SUBORDINATE_OF
# [CLS] помощник президента по национальной безопасности [SEP] президента [SEP]
#
# expected: 0
# found: 1 ( [[-2.3898525  1.1732717]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] секретарь Совета безопасности [SEP] Совета безопасности [SEP]
#
# expected: 0
# found: 1 ( [[-3.1885645  1.8711902]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] глава МВД [SEP] МВД [SEP]
#
# expected: 0
# found: 1 ( [[-3.1410043  1.835873 ]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] Вице - президент Российской академии образования [SEP] Российской академии образования [SEP]
#
# expected: 0
# found: 1 ( [[-3.204141   2.0076234]] )
# ORGANIZATION ---> COUNTRY : None
# [CLS] партии президента Зимбабве [SEP] Зимбабве [SEP]
#
# expected: 0
# found: 1 ( [[-3.0609143  1.9380833]] )
# PROFESSION ---> COUNTRY : None
# [CLS] президента Зимбабве [SEP] Зимбабве [SEP]
#
# expected: 0
# found: 1 ( [[-0.51508886  0.08624738]] )
# PROFESSION ---> EVENT : None
# [CLS] президентские [SEP] президентские и парламентские выборы [SEP]
#
# expected: 0
# found: 1 ( [[-3.1649928  1.8528904]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] лидер " Африканского национального союза Зимбабве — Патриотический фронт " [SEP] Африканского национального союза Зимбабве — Патриотический фронт [SEP]
#
# expected: 0
# found: 1 ( [[-3.0466406  1.7681527]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] глава оппозиционного " Движения за демократические перемены " [SEP] Движения за демократические перемены [SEP]
#
# expected: 0
# found: 1 ( [[-0.70137113  0.12556633]] )
# PROFESSION ---> EVENT : None
# [CLS] президентских [SEP] президентских выборах [SEP]
#
# expected: 0
# found: 1 ( [[-0.56197745  0.09478619]] )
# PROFESSION ---> EVENT : None
# [CLS] президентские [SEP] президентские выборы [SEP]
#
# expected: 0
# found: 1 ( [[-2.7315104  1.6664963]] )
# ORGANIZATION ---> COUNTRY : None
# [CLS] Сеть поддержки выборов в Зимбабве [SEP] Зимбабве [SEP]
#
# expected: 1
# found: 0 ( [[ 4.010859  -2.9364405]] )
# EVENT ---> LOCATION : TAKES_PLACE_IN
# [CLS] высадился на Луне [SEP] Луне [SEP]
#
# expected: 0
# found: 1 ( [[-0.56197745  0.09478619]] )
# PROFESSION ---> EVENT : None
# [CLS] президентские [SEP] президентские выборы [SEP]
#
# expected: 0
# found: 1 ( [[-0.56197745  0.09478619]] )
# PROFESSION ---> EVENT : None
# [CLS] президентские [SEP] президентские выборы [SEP]
#
# expected: 1
# found: 0 ( [[ 3.3666816 -2.6698663]] )
# ORGANIZATION ---> STATE_OR_PROVINCE : HEADQUARTERED_IN
# [CLS] Туарегское Национальное движение за освобождение Азавада [SEP] Азавада [SEP]
#
# expected: 0
# found: 1 ( [[-3.3610327  1.8919164]] )
# ORGANIZATION ---> NATIONALITY : None
# [CLS] повстанческих группировок туарегов [SEP] туарегов [SEP]
#
# expected: 1
# found: 0 ( [[ 4.0798593 -3.3985891]] )
# PROFESSION ---> ORGANIZATION : WORKPLACE
# [CLS] главы правительства [SEP] правительства [SEP]
#
# expected: 1
# found: 0 ( [[ 4.1259    -3.2519498]] )
# ORGANIZATION ---> COUNTRY : HEADQUARTERED_IN
# [CLS] Rassemblement pour le Mali [SEP] Mal [SEP]
#
# expected: 0
# found: 1 ( [[-3.1881409  1.870714 ]] )
# PROFESSION ---> ORGANIZATION : None
# [CLS] председателем переходного правительства Мали [SEP] переходного правительства Мали [SEP]
#
# expected: 0
# found: 1 ( [[-2.7350464  1.4970725]] )
# ORGANIZATION ---> LOCATION : None
# [CLS] Национальная конвенция за солидарность Африки [SEP] Африки [SEP]
#
# expected: 0
# found: 1 ( [[-2.264591   1.1600779]] )
# LOCATION ---> COUNTRY : None
# [CLS] границе с Китаем [SEP] Китаем [SEP]
#
#
# test loss= 0.6128
#  test accuracy = 0.8809, F1 = 0.8416751787538304
# /kernel/lib/python3.7/site-packages/ml_kernel/kernel.py:859: UserWarning: The following variables cannot be serialized: pbar
#   warnings.warn(message)

# %%
#!g1.1
from collections import Counter
l = []
for true, pred, t in zip(y_true, y_pred, tags):
    if (true != pred):
        l.append((t[0][0], t[1][0]))
Counter(l).most_common()

# %%
#!g1.1
tags[0][1][0]
