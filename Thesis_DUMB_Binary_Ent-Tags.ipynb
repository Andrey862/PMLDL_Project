# %%
# !git clone https://github.com/nerel-ds/NEREL

# %%
# !unzip NEREL-v1.0.zip -d NEREL

# %%
## Read the data# Reading files
from collections import namedtuple
import re
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import nltk

Ann = namedtuple('annotation', ['tag', 'start1', 'end1', 'start2', 'end2', 'text'])
Rel = namedtuple('relationship', ['tag', 'arg1', 'arg2'])

def read_files(folder):
    filenames = sorted(set(e[:e.rfind('.')] for e in os.listdir(folder)))[1:]
    
    texts, entities, relationships  = [], [], []
    for file in tqdm(filenames):
       # if (not file): continue
        path1 = os.path.join(folder, file+'.txt')
        path2 = os.path.join(folder, file+'.ann')
        if (not os.path.exists(path2)):
            print(f'{path2} not found')
            continue
            #with open(path2, 'w'):
            #    pass
            
        with open(path1, 'r', encoding="utf8") as text, open(path2, 'r', encoding="utf8") as ann:
            texts.append(text.read())

            file_entities = {}
            file_relationship = []
            regex_ent = r'T(?P<id>\d+)\s(?P<tag>\w+)\s(?P<start1>\d+) (?P<end1>\d+)(;(?P<start2>\d+) (?P<end2>\d+))?\s(?P<text>.*)'
            regex_rel = r'R(?P<id>\d+)\s(?P<tag>\w+)\sArg1:T(?P<arg1>\d+) Arg2:T(?P<arg2>\d+)'
            
            
            for row in sorted(ann.readlines(), reverse=True):
                #print(row)
                match_ent = re.match(regex_ent, row)
                match_rel = re.match(regex_rel, row)
                if (match_ent):
                    res = match_ent.groupdict()
                    res['start1'] = int(res['start1'])
                    res['end1'] = int(res['end1'])
                    if (res['start2'] is not None):
                        res['start2'] = int(res['start2'])
                        res['end2'] = int(res['end2'])
                    id = res.pop('id')
                    file_entities[id] = Ann(**res)
                elif (match_rel):
                    try:
                        res = match_rel.groupdict()
                        res['arg1'] = file_entities[res['arg1']]
                        res['arg2'] = file_entities[res['arg2']]
                        id = res.pop('id')
                        file_relationship.append(Rel(**res))
                    except KeyError as e:
                        print(f'not found T{e} row={row}')
                else:
                    print(f'incorrect format in: row={row} file={file}')
            entities.append(file_entities)
            relationships.append(file_relationship)
    entities = [sorted(e.values(), key = lambda x: (x.start1, x.end1)) for e in entities]
    return texts, entities, relationships, filenames

# %%
folder = 'NEREL/NEREL-v1.0/train'
texts, entities, relationships, filenames = read_files(folder)
# Out:
# incorrect format in: row=По словам очевидцев пешехо
#  file=21013_text
# 100%|██████████| 745/745 [00:02<00:00, 289.36it/s]

# %%
def in_range(range1, range2):
    # range1 in range2
    if range1[0] is None: return True
    if range2[0] is None: return False
    return int(range2[0]) <= int(range1[0]) and int(range2[1]) >= int(range1[1])

def is_nested_anns(ent1: Ann, ent2: Ann):
    # ent 1 in ent 2
    res = True
    ent1_range1 = (ent1.start1, ent1.end1)
    ent1_range2 = (ent1.start2, ent1.end2)
    ent2_range1 = (ent2.start1, ent2.end1)
    ent2_range2 = (ent2.start2, ent2.end2)
    #print(f'{ent1_range1=} {ent1_range2=} {ent1_range2=} {ent2_range2=}')
    res = res and (in_range(ent1_range1, ent2_range1) or in_range(ent1_range1, ent2_range2))
    res = res and (in_range(ent1_range2, ent2_range1) or in_range(ent1_range2, ent2_range2))
    return res


def is_nested_anns2(ent1: Ann, ent2: Ann):
    return is_nested_anns(ent1,ent2) or is_nested_anns(ent2, ent1)

def is_nested(rel: Rel):
    return is_nested_anns(rel.arg1, rel.arg2) or is_nested_anns(rel.arg2, rel.arg1)

# %% [markdown]
# ![](https://i.imgur.com/tgDfc8i.png)             | ![](https://i.imgur.com/oWa5vWo.png)
# :-------------------------:|:-------------------------:

# %%
pre_dataset = []

for text_id in range(len(texts)):
    relationships_nested = {(e.arg1, e.arg2):e for e in relationships[text_id] if is_nested(e)}
    nes = []
    for i in range(len(entities[text_id])):
        # O(n^2) eeeeeeeeee
        for j in range(i+1, len(entities[text_id])):
            if (is_nested_anns2(entities[text_id][i], entities[text_id][j])):
                nes.append((entities[text_id][i], entities[text_id][j]))
    for e in nes:
        if (e in relationships_nested):
            pre_dataset.append((*e, relationships_nested[e].tag))
        elif ((e[1], e[0]) in relationships_nested):
            pre_dataset.append((e[1], e[0], relationships_nested[(e[1], e[0])].tag))
        else:
            pre_dataset.append((*e, 'None'))
#             pre_dataset.append((e[1], e[0], 'None'))

# %% [markdown]
# # AAA

# %%
from random import shuffle
from copy import copy
rs = copy(pre_dataset)
l = len(rs)
shuffle(rs)
split = int(l*0.85)
train = rs[:split]
test = rs[split:]
len(train), len(test)
# Out:
# (9498, 1677)

# %%
from collections import defaultdict
d = defaultdict(int)
for e in train:
    if (e[2] == 'None'):
        d[tuple(sorted([e[0].tag, e[1].tag]))] -= 1
    else:
        d[tuple(sorted([e[0].tag, e[1].tag]))] += 1

# %%
d
# Out:
# defaultdict(int,
#             {('ORGANIZATION', 'PROFESSION'): 413,
#              ('PROFESSION', 'PROFESSION'): -1289,
#              ('ORGANIZATION', 'ORGANIZATION'): -366,
#              ('COUNTRY', 'ORGANIZATION'): 489,
#              ('LOCATION', 'ORGANIZATION'): 8,
#              ('COUNTRY', 'LAW'): -35,
#              ('PROFESSION', 'STATE_OR_PROVINCE'): 50,
#              ('LAW', 'LOCATION'): 1,
#              ('EVENT', 'NUMBER'): -100,
#              ('AWARD', 'EVENT'): 6,
#              ('EVENT', 'EVENT'): -248,
#              ('DATE', 'PENALTY'): -62,
#              ('ORDINAL', 'PROFESSION'): -18,
#              ('LAW', 'ORDINAL'): -181,
#              ('COUNTRY', 'PROFESSION'): 257,
#              ('IDEOLOGY', 'ORGANIZATION'): 56,
#              ('ORGANIZATION', 'PRODUCT'): 8,
#              ('EVENT', 'ORDINAL'): -36,
#              ('PROFESSION', 'RELIGION'): -2,
#              ('CITY', 'ORGANIZATION'): 208,
#              ('LAW', 'LAW'): -121,
#              ('PERSON', 'WORK_OF_ART'): -26,
#              ('ORGANIZATION', 'RELIGION'): 42,
#              ('CRIME', 'CRIME'): -56,
#              ('COUNTRY', 'NATIONALITY'): 35,
#              ('EVENT', 'FACILITY'): -12,
#              ('DATE', 'EVENT'): 39,
#              ('CRIME', 'IDEOLOGY'): -12,
#              ('AWARD', 'AWARD'): -136,
#              ('CITY', 'PROFESSION'): -3,
#              ('DISTRICT', 'ORGANIZATION'): 19,
#              ('CITY', 'FACILITY'): 20,
#              ('DISEASE', 'DISEASE'): -47,
#              ('IDEOLOGY', 'PROFESSION'): -11,
#              ('PENALTY', 'PENALTY'): -87,
#              ('AWARD', 'PERSON'): -15,
#              ('DATE', 'TIME'): -92,
#              ('AWARD', 'MONEY'): -1,
#              ('AWARD', 'PROFESSION'): -57,
#              ('CRIME', 'LAW'): -13,
#              ('FACILITY', 'ORGANIZATION'): 8,
#              ('EVENT', 'ORGANIZATION'): 4,
#              ('LAW', 'PERSON'): 11,
#              ('NATIONALITY', 'PROFESSION'): -9,
#              ('ORGANIZATION', 'STATE_OR_PROVINCE'): 55,
#              ('FACILITY', 'PERSON'): -46,
#              ('AWARD', 'STATE_OR_PROVINCE'): 5,
#              ('ORDINAL', 'PERSON'): -52,
#              ('CITY', 'EVENT'): 63,
#              ('IDEOLOGY', 'WORK_OF_ART'): -1,
#              ('ORDINAL', 'TIME'): -7,
#              ('DISTRICT', 'PROFESSION'): 10,
#              ('COUNTRY', 'EVENT'): 31,
#              ('FACILITY', 'LOCATION'): -8,
#              ('DISTRICT', 'LOCATION'): 15,
#              ('LOCATION', 'PROFESSION'): -22,
#              ('EVENT', 'PROFESSION'): -36,
#              ('FACILITY', 'NUMBER'): -13,
#              ('DATE', 'DATE'): -24,
#              ('FACILITY', 'FACILITY'): 3,
#              ('LAW', 'ORGANIZATION'): -11,
#              ('LOCATION', 'LOCATION'): 10,
#              ('COUNTRY', 'MONEY'): -30,
#              ('ORGANIZATION', 'PERSON'): -7,
#              ('IDEOLOGY', 'IDEOLOGY'): -19,
#              ('CRIME', 'ORGANIZATION'): -1,
#              ('DATE', 'LAW'): 7,
#              ('CRIME', 'STATE_OR_PROVINCE'): -1,
#              ('CRIME', 'PROFESSION'): 6,
#              ('COUNTRY', 'CRIME'): -6,
#              ('AWARD', 'ORDINAL'): -17,
#              ('AGE', 'FACILITY'): -4,
#              ('ORDINAL', 'ORGANIZATION'): -20,
#              ('EVENT', 'LAW'): -2,
#              ('DATE', 'PROFESSION'): -1,
#              ('CITY', 'LOCATION'): 3,
#              ('LANGUAGE', 'PRODUCT'): -2,
#              ('LAW', 'PROFESSION'): -7,
#              ('CRIME', 'EVENT'): -3,
#              ('CITY', 'WORK_OF_ART'): -8,
#              ('PERSON', 'PERSON'): -6,
#              ('DISTRICT', 'ORDINAL'): -2,
#              ('NUMBER', 'PRODUCT'): -14,
#              ('AWARD', 'DATE'): 18,
#              ('AWARD', 'COUNTRY'): 26,
#              ('CRIME', 'NUMBER'): -6,
#              ('AWARD', 'LOCATION'): 3,
#              ('PRODUCT', 'WORK_OF_ART'): -1,
#              ('CITY', 'STATE_OR_PROVINCE'): 2,
#              ('COUNTRY', 'PERSON'): 0,
#              ('CITY', 'DISTRICT'): 0,
#              ('LOCATION', 'WORK_OF_ART'): -4,
#              ('CITY', 'COUNTRY'): 10,
#              ('CITY', 'ORDINAL'): -1,
#              ('CITY', 'LAW'): -2,
#              ('NATIONALITY', 'ORGANIZATION'): -16,
#              ('AGE', 'EVENT'): -4,
#              ('PERSON', 'PROFESSION'): -3,
#              ('COUNTRY', 'COUNTRY'): -1,
#              ('PRODUCT', 'PROFESSION'): -6,
#              ('EVENT', 'PERSON'): -10,
#              ('PROFESSION', 'WORK_OF_ART'): -2,
#              ('ORDINAL', 'ORDINAL'): -1,
#              ('CITY', 'TIME'): -6,
#              ('COUNTRY', 'LOCATION'): 21,
#              ('COUNTRY', 'FACILITY'): -5,
#              ('FAMILY', 'PERSON'): 6,
#              ('FACILITY', 'ORDINAL'): -8,
#              ('NUMBER', 'PENALTY'): -8,
#              ('EVENT', 'LOCATION'): 13,
#              ('COUNTRY', 'PRODUCT'): 3,
#              ('DATE', 'ORGANIZATION'): 1,
#              ('NUMBER', 'ORGANIZATION'): -14,
#              ('DISTRICT', 'FACILITY'): 3,
#              ('AWARD', 'ORGANIZATION'): 6,
#              ('WORK_OF_ART', 'WORK_OF_ART'): -1,
#              ('MONEY', 'NUMBER'): -1,
#              ('LAW', 'PRODUCT'): -5,
#              ('MONEY', 'PENALTY'): -6,
#              ('EVENT', 'PENALTY'): -3,
#              ('FAMILY', 'PROFESSION'): -1,
#              ('IDEOLOGY', 'LAW'): -8,
#              ('LOCATION', 'NUMBER'): -4,
#              ('LOCATION', 'STATE_OR_PROVINCE'): 1,
#              ('COUNTRY', 'WORK_OF_ART'): -6,
#              ('EVENT', 'NATIONALITY'): 2,
#              ('EVENT', 'STATE_OR_PROVINCE'): 2,
#              ('EVENT', 'IDEOLOGY'): 0,
#              ('ORGANIZATION', 'WORK_OF_ART'): -2,
#              ('PRODUCT', 'PRODUCT'): 1,
#              ('FACILITY', 'PROFESSION'): -8,
#              ('EVENT', 'RELIGION'): -1,
#              ('DISEASE', 'EVENT'): -5,
#              ('NUMBER', 'WORK_OF_ART'): -5,
#              ('EVENT', 'WORK_OF_ART'): -2,
#              ('FACILITY', 'RELIGION'): 1,
#              ('FACILITY', 'STATE_OR_PROVINCE'): 2,
#              ('FACILITY', 'WORK_OF_ART'): -4,
#              ('RELIGION', 'RELIGION'): -1,
#              ('NATIONALITY', 'NATIONALITY'): -5,
#              ('DISTRICT', 'WORK_OF_ART'): -1,
#              ('LAW', 'NUMBER'): -3,
#              ('AWARD', 'PRODUCT'): -2,
#              ('CRIME', 'MONEY'): -1,
#              ('IDEOLOGY', 'RELIGION'): -4,
#              ('AGE', 'CRIME'): -2,
#              ('AWARD', 'CITY'): -2,
#              ('TIME', 'TIME'): -4,
#              ('NATIONALITY', 'WORK_OF_ART'): -5,
#              ('IDEOLOGY', 'PRODUCT'): -2,
#              ('DISEASE', 'FACILITY'): -1,
#              ('COUNTRY', 'PENALTY'): -1,
#              ('MONEY', 'MONEY'): -1,
#              ('AGE', 'DATE'): -1,
#              ('CRIME', 'PERSON'): 1,
#              ('DISTRICT', 'PERSON'): -1,
#              ('DISEASE', 'NUMBER'): -1,
#              ('LOCATION', 'ORDINAL'): -1,
#              ('DISTRICT', 'EVENT'): -1,
#              ('PERSON', 'PRODUCT'): 1,
#              ('LOCATION', 'TIME'): -1,
#              ('CITY', 'CRIME'): -1,
#              ('AWARD', 'DISTRICT'): 1,
#              ('CRIME', 'LOCATION'): -1,
#              ('CITY', 'RELIGION'): -1,
#              ('FACILITY', 'NATIONALITY'): -2,
#              ('LAW', 'NATIONALITY'): -2,
#              ('CRIME', 'PRODUCT'): -2,
#              ('LANGUAGE', 'ORGANIZATION'): -1,
#              ('AGE', 'LAW'): -1,
#              ('NUMBER', 'TIME'): -1,
#              ('STATE_OR_PROVINCE', 'WORK_OF_ART'): -1,
#              ('COUNTRY', 'FAMILY'): -1,
#              ('LAW', 'STATE_OR_PROVINCE'): 1,
#              ('DATE', 'NUMBER'): -1,
#              ('EVENT', 'TIME'): -1,
#              ('ORDINAL', 'WORK_OF_ART'): -1,
#              ('DATE', 'PRODUCT'): -1,
#              ('DISEASE', 'PERSON'): -1,
#              ('CRIME', 'ORDINAL'): -1,
#              ('DISEASE', 'PRODUCT'): 1,
#              ('CRIME', 'FACILITY'): -1,
#              ('DATE', 'MONEY'): -1,
#              ('NUMBER', 'PROFESSION'): -1,
#              ('CITY', 'PERSON'): -1})

# %%
correct = 0
wrong = 0
undeterment = 0
for e in test:
    ture = e[2] != 'None' # True = relation present
    pred = d[tuple(sorted([e[0].tag, e[1].tag]))] > 0 # False = relation abcent
    if (d[tuple(sorted([e[0].tag, e[1].tag]))] == 0):
        undeterment+=1
    if (ture == pred):
        correct +=1
    else:
        wrong += 1

# %%
correct, wrong, undeterment
# Out:
# (1322, 355, 7)

# %%
(correct)/(correct + wrong + undeterment)
# Out:
# 0.7850356294536817

# %%
y_true = []
y_pred = []
for e in test:
    ture = e[2] != 'None' # True = relation present
    pred = d[tuple(sorted([e[0].tag, e[1].tag]))] > 0 # False = relation abcent
    y_true.append(ture)
    y_pred.append(pred)
    
from sklearn.metrics import f1_score
f1_score(y_true, y_pred)
# Out:
# 0.7491166077738516
